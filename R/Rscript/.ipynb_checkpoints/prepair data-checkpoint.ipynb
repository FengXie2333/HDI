# %%
setwd("D:/yangyang")

# %%
t<- read.csv("D:/common/project/yangyangli/GSEA.csv")

# %%
head(t)
# Out:
#   锘縄D_REF Gene.symbol Gene.title
# 1 10344620
# 2 10344622  Pdhb        pyruvate dehydrogenase (lipoamide) beta
# 3 10344624  Lypla1      lysophospholipase 1
# 4 10344633  Tcea1       transcription elongation factor A (SII) 1
# 5 10344637  Atp6v1h     ATPase, H+ transporting, lysosomal V1 subunit H
# 6 10344653  Oprk1       opioid receptor, kappa 1
#   GSM921176 GSM921177 GSM921178 GSM921179 GSM921180 GSM921181 GSM921182 ...
# 1  25.7438   18.7212   19.2857   22.4073   20.7328   19.6298   25.2262  ...
# 2 256.9177  192.9730  193.6664  212.4845  181.9338  188.9743  212.6661  ...
# 3 577.5795  663.2409  587.5758  582.1440  418.0202  464.9468  424.0452  ...
# 4 679.0259  779.1636  697.9711  842.6017  802.9366  719.9879  769.2409  ...
# 5 375.9733  341.5425  316.3979  272.0636  276.6603  295.2028  214.8913  ...
# 6  16.3057   17.4627   13.1043   16.9326   20.2424   16.5501   15.3625  ...
#   GSM921220 GSM921221 GSM921222 GSM921223 GSM921224 GSM921225 GSM921226
# ...

# %%
t <- t[,-1]

# %%
head(t)
# Out:
#   Gene.symbol Gene.title                                      GSM921176
# 1 NA          NA                                               25.7438
# 2 Pdhb        pyruvate dehydrogenase (lipoamide) beta         256.9177
# 3 Lypla1      lysophospholipase 1                             577.5795
# 4 Tcea1       transcription elongation factor A (SII) 1       679.0259
# 5 Atp6v1h     ATPase, H+ transporting, lysosomal V1 subunit H 375.9733
# 6 Oprk1       opioid receptor, kappa 1                         16.3057
#   GSM921177 GSM921178 GSM921179 GSM921180 GSM921181 GSM921182 GSM921183 ...
# 1  18.7212   19.2857   22.4073   20.7328   19.6298   25.2262   21.3046  ...
# 2 192.9730  193.6664  212.4845  181.9338  188.9743  212.6661  259.4896  ...
# 3 663.2409  587.5758  582.1440  418.0202  464.9468  424.0452  534.6844  ...
# 4 779.1636  697.9711  842.6017  802.9366  719.9879  769.2409  743.6042  ...
# 5 341.5425  316.3979  272.0636  276.6603  295.2028  214.8913  277.5443  ...
# ...

# %%
t[t ==''] <- NA

# %%
t1 <- t[,c(1,2,3,22:27)]

# %%
write.csv(t, file='GSEA_all.csv')

# %%
t[t == ''] <- 'na'
# Out:
# Warning message in `[<-.factor`(`*tmp*`, thisvar, value = "na"):
# "invalid factor level, NA generated"

# %%
head(t1)
# Out:
#   锘縄D_REF Gene.symbol Gene.title
# 1 10344620
# 2 10344622  Pdhb        pyruvate dehydrogenase (lipoamide) beta
# 3 10344624  Lypla1      lysophospholipase 1
# 4 10344633  Tcea1       transcription elongation factor A (SII) 1
# 5 10344637  Atp6v1h     ATPase, H+ transporting, lysosomal V1 subunit H
# 6 10344653  Oprk1       opioid receptor, kappa 1
#   GSM921194 GSM921195 GSM921196 GSM921197 GSM921198 GSM921199
# 1  19.7509   22.1273   22.4210   21.7409   18.7338   24.8073
# 2 242.9779  272.9883  264.3011  252.7832  239.5595  290.8694
# 3 544.1563  352.8590  504.9503  476.8741  532.4983  420.7629
# 4 778.0668  567.0223  572.8301  725.8726  780.2594  586.4676
# 5 278.2330  254.2030  258.1014  250.7310  248.8939  294.1739
# 6  15.4003   19.7807   15.5555   18.7824   17.0589   13.6362

# %%
write.csv(t1, file="GSEA_selecct.csv")

# %%
dim(t1)
# Out:
# [1] 25200     8

# %%
t2 <- t[,c(1,2,3)]

# %%
head(t2)
# Out:
#   锘縄D_REF Gene.symbol Gene.title
# 1 10344620
# 2 10344622  Pdhb        pyruvate dehydrogenase (lipoamide) beta
# 3 10344624  Lypla1      lysophospholipase 1
# 4 10344633  Tcea1       transcription elongation factor A (SII) 1
# 5 10344637  Atp6v1h     ATPase, H+ transporting, lysosomal V1 subunit H
# 6 10344653  Oprk1       opioid receptor, kappa 1

# %%
t2[t2 ==  ''] <- NA

# %%
write.csv(t2, file='GSEA_chip.csv')
